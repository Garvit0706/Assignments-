# %%
1: Calculate the Pearson correlation coefficient between study time and exam scores
Data:

Study Time (hours): 
𝑋
=
[
2
,
3
,
4
,
5
,
6
,
7
,
8
,
9
,
10
]
X=[2,3,4,5,6,7,8,9,10]
Exam Scores (marks): 
𝑌
=
[
50
,
55
,
60
,
65
,
70
,
75
,
80
,
85
,
90
]
Y=[50,55,60,65,70,75,80,85,90]

import numpy as np

# Data
study_time = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10])
exam_scores = np.array([50, 55, 60, 65, 70, 75, 80, 85, 90])

# Pearson correlation coefficient
pearson_corr = np.corrcoef(study_time, exam_scores)[0, 1]
pearson_corr

# %%
Q2: Calculate the Spearman's rank correlation between sleep and job satisfaction
Data:

Sleep (hours): 
𝑋
=
[
7
,
6
,
8
,
5
,
6
,
7
,
9
,
4
,
6
,
5
]
X=[7,6,8,5,6,7,9,4,6,5]
Job Satisfaction (scale 1-10): 
𝑌
=
[
6
,
5
,
7
,
4
,
5
,
6
,
8
,
3
,
5
,
4
]
Y=[6,5,7,4,5,6,8,3,5,4]
Formula:
𝑟
𝑠
=
1
−
6
∑
𝑑
𝑖
2
𝑛
(
𝑛
2
−
1
)
r 
s
​
 =1− 
n(n 
2
 −1)
6∑d 
i
2
​
 
​
 

where 
𝑑
𝑖
d 
i
​
  is the difference between the ranks of corresponding values.

from scipy.stats import spearmanr

# Data
sleep = [7, 6, 8, 5, 6, 7, 9, 4, 6, 5]
job_satisfaction = [6, 5, 7, 4, 5, 6, 8, 3, 5, 4]

# Spearman's rank correlation
spearman_corr, _ = spearmanr(sleep, job_satisfaction)
spearman_corr

# %%
Q3: Compare Pearson and Spearman correlations between exercise hours and BMI
Data (hypothetical example for illustration):

Exercise Hours: 
𝑋= [data]
BMI:𝑌=[data]

import numpy as np
from scipy.stats import spearmanr

# Hypothetical data for 50 participants
np.random.seed(0)
exercise_hours = np.random.randint(1, 10, 50)
bmi = np.random.randint(18, 30, 50)

# Pearson correlation coefficient
pearson_corr = np.corrcoef(exercise_hours, bmi)[0, 1]

# Spearman's rank correlation
spearman_corr, _ = spearmanr(exercise_hours, bmi)

pearson_corr, spearman_corr

# %%
Q4: Calculate Pearson correlation between TV watching hours and physical activity
Data (hypothetical example for illustration):

TV Watching Hours: 
X= [data]
Physical Activity Hours: 
Y= [data]
import numpy as np

# Hypothetical data for 50 participants
np.random.seed(0)
tv_hours = np.random.randint(1, 5, 50)
physical_activity_hours = np.random.randint(1, 10, 50)

# Pearson correlation coefficient
pearson_corr = np.corrcoef(tv_hours, physical_activity_hours)[0, 1]
pearson_corr

# %%
Q5: Calculating covariance matrix
Given the hypothetical data for age and soft drink preference (e.g., encoded numerically).

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Example data
data = pd.DataFrame({
    'Age': [23, 45, 31, 34],
    'SoftDrinkPreference': ['BrandA', 'BrandB', 'BrandA', 'BrandC']
})

# Label encoding
label_encoder = LabelEncoder()
data['SoftDrinkPreference_Encoded'] = label_encoder.fit_transform(data['SoftDrinkPreference'])

# Covariance matrix
cov_matrix = data[['Age', 'SoftDrinkPreference_Encoded']].cov()
print(cov_matrix)

# %%
Q6: Calculate the Pearson correlation coefficient between sales calls and sales
Data (hypothetical example for illustration):

Sales Calls per Day: 
X= [data]
Sales per Week: 
Y= [data]

import numpy as np

# Hypothetical data for 30 sales representatives
np.random.seed(0)
sales_calls = np.random.randint(1, 20, 30)
sales_per_week = np.random.randint(1, 10, 30)

# Pearson correlation coefficient
pearson_corr = np.corrcoef(sales_calls, sales_per_week)[0, 1]
pearson_corr
