# %% [markdown]
# 1. What is Bayes' Theorem?
# Bayes' Theorem is a fundamental concept in probability theory that describes the likelihood of an event occurring based on prior knowledge of conditions that might be related to the event. It provides a way to update the probability estimate for an event as more evidence or information becomes available.

# %% [markdown]
# Q2. What is the Formula for Bayes' Theorem?
# The formula for Bayes' Theorem is:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# where:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) is the posterior probability, the probability of event
# 𝐴
# A occurring given that
# 𝐵
# B is true.
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) is the likelihood, the probability of event
# 𝐵
# B occurring given that
# 𝐴
# A is true.
# 𝑃
# (
# 𝐴
# )
# P(A) is the prior probability, the probability of event
# 𝐴
# A occurring before considering
# 𝐵
# B.
# 𝑃
# (
# 𝐵
# )
# P(B) is the marginal likelihood, the total probability of event
# 𝐵
# B occurring under all conditions.

# %%
Q3. How is Bayes' Theorem Used in Practice?
Bayes' Theorem is used in various practical applications, such as:

Medical Diagnosis: Estimating the probability of a disease given the presence of certain symptoms.
Spam Filtering: Determining the likelihood that an email is spam based on the occurrence of specific words or phrases.
Risk Assessment: Evaluating the risk of an event, such as a financial collapse, based on prior incidents and new data.
Machine Learning (Naive Bayes Classifier): Predicting the class of a data point by combining prior information about class
probabilities with observed feature values.

# %% [markdown]
# Q4. What is the Relationship Between Bayes' Theorem and Conditional Probability?
# Bayes' Theorem is directly related to conditional probability. Conditional probability is the probability of an event occurring given that another event has already occurred. Bayes' Theorem provides a way to calculate this conditional probability by reversing the conditional relationship:
#
# Conditional Probability:
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B)
# Bayes' Theorem:
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# =
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# 𝑃
# (
# 𝐵
# )
# P(A∣B)=
# P(B)
# P(B∣A)⋅P(A)
# ​
#
# Bayes' Theorem uses the known conditional probability
# 𝑃
# (
# 𝐵
# ∣
# 𝐴
# )
# P(B∣A) (the probability of
# 𝐵
# B given
# 𝐴
# A) to compute
# 𝑃
# (
# 𝐴
# ∣
# 𝐵
# )
# P(A∣B) (the probability of
# 𝐴
# A given
# 𝐵
# B).

# %%
Q5. How Do You Choose Which Type of Naive Bayes Classifier to Use for Any Given Problem?
There are three main types of Naive Bayes classifiers, and the choice depends on the nature of the data:

Gaussian Naive Bayes:

Use Case: When the features are continuous and normally distributed.
Example: Iris dataset, where the features (e.g., petal length, sepal width) are continuous variables.
Multinomial Naive Bayes:

Use Case: When the features represent discrete counts or frequencies.
Example: Text classification, where features are word counts in documents.
Bernoulli Naive Bayes:

Use Case: When the features are binary (0/1) values.
Example: Document classification with binary word occurrence indicators (whether a word appears or not).

# %% [markdown]
# Q6. Assignment: Naive Bayes Classification
# Given the dataset:
#
# Class	X1=1	X1=2	X1=3	X2=1	X2=2	X2=3	X2=4
# A	3	3	4	4	3	3	3
# B	2	2	1	2	2	2	3
# We want to classify a new instance with features
# 𝑋
# 1
# =
# 3
# X1=3 and
# 𝑋
# 2
# =
# 4
# X2=4.
#
# Step 1: Calculate the Likelihoods
# For Class A:
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐴
# )
# =
# 4
# 3
# +
# 3
# +
# 4
# =
# 4
# 10
# =
# 0.4
# P(X1=3∣A)=
# 3+3+4
# 4
# ​
#  =
# 10
# 4
# ​
#  =0.4
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐴
# )
# =
# 3
# 4
# +
# 3
# +
# 3
# +
# 3
# =
# 3
# 13
# ≈
# 0.231
# P(X2=4∣A)=
# 4+3+3+3
# 3
# ​
#  =
# 13
# 3
# ​
#  ≈0.231
# For Class B:
#
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐵
# )
# =
# 1
# 2
# +
# 2
# +
# 1
# =
# 1
# 5
# =
# 0.2
# P(X1=3∣B)=
# 2+2+1
# 1
# ​
#  =
# 5
# 1
# ​
#  =0.2
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐵
# )
# =
# 3
# 2
# +
# 2
# +
# 2
# +
# 3
# =
# 3
# 9
# =
# 0.333
# P(X2=4∣B)=
# 2+2+2+3
# 3
# ​
#  =
# 9
# 3
# ​
#  =0.333
# Step 2: Calculate the Posterior Probabilities Using Bayes' Theorem
# Assuming equal prior probabilities for each class
# 𝑃
# (
# 𝐴
# )
# =
# 𝑃
# (
# 𝐵
# )
# =
# 0.5
# P(A)=P(B)=0.5:
#
# For Class A:
#
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐴
# )
# ⋅
# 𝑃
# (
# 𝐴
# )
# P(A∣X1=3,X2=4)∝P(X1=3∣A)⋅P(X2=4∣A)⋅P(A)
#
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 0.4
# ⋅
# 0.231
# ⋅
# 0.5
# =
# 0.0462
# P(A∣X1=3,X2=4)∝0.4⋅0.231⋅0.5=0.0462
# For Class B:
#
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 𝑃
# (
# 𝑋
# 1
# =
# 3
# ∣
# 𝐵
# )
# ⋅
# 𝑃
# (
# 𝑋
# 2
# =
# 4
# ∣
# 𝐵
# )
# ⋅
# 𝑃
# (
# 𝐵
# )
# P(B∣X1=3,X2=4)∝P(X1=3∣B)⋅P(X2=4∣B)⋅P(B)
#
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# ∝
# 0.2
# ⋅
# 0.333
# ⋅
# 0.5
# =
# 0.0333
# P(B∣X1=3,X2=4)∝0.2⋅0.333⋅0.5=0.0333
# Step 3: Predict the Class
# Since
# 𝑃
# (
# 𝐴
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# >
# 𝑃
# (
# 𝐵
# ∣
# 𝑋
# 1
# =
# 3
# ,
# 𝑋
# 2
# =
# 4
# )
# P(A∣X1=3,X2=4)>P(B∣X1=3,X2=4), Naive Bayes would predict the new instance to belong to Class A.
