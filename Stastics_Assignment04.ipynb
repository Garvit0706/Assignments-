# %%
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with an example.
Probability Mass Function (PMF):

Used for discrete random variables.
Describes the probability that a discrete random variable is exactly equal to some value.
Example: Let 
𝑋
X be the outcome of rolling a fair six-sided die. The PMF of 
𝑋
X is:
𝑃
(
𝑋
=
𝑥
)
=
{
1
6
if 
𝑥
∈
{
1
,
2
,
3
,
4
,
5
,
6
}
0
otherwise
P(X=x)={ 
6
1
​
 
0
​
  
if x∈{1,2,3,4,5,6}
otherwise
​
 
Probability Density Function (PDF):

Used for continuous random variables.
Describes the likelihood of a random variable to take on a particular value.
The area under the PDF curve within a given range represents the probability of the variable falling within that range.
Example: For a normal distribution with mean 
𝜇
=
0
μ=0 and standard deviation 
𝜎
=
1
σ=1:
𝑓
(
𝑥
)
=
1
2
𝜋
𝑒
−
𝑥
2
2
f(x)= 
2π
​
 
1
​
 e 
− 
2
x 
2
 
​

# %%
Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why is CDF used?
Cumulative Density Function (CDF):

Describes the probability that a random variable 
𝑋
X will take a value less than or equal to 
𝑥
x.
For a discrete random variable 
𝑋
X with PMF 
𝑝
(
𝑥
)
p(x):
𝐹
(
𝑥
)
=
𝑃
(
𝑋
≤
𝑥
)
=
∑
𝑡
≤
𝑥
𝑝
(
𝑡
)
F(x)=P(X≤x)= 
t≤x
∑
​
 p(t)
For a continuous random variable 
𝑋
X with PDF 
𝑓
(
𝑥
)
f(x):
𝐹
(
𝑥
)
=
𝑃
(
𝑋
≤
𝑥
)
=
∫
−
∞
𝑥
𝑓
(
𝑡
)
 
𝑑
𝑡
F(x)=P(X≤x)=∫ 
−∞
x
​
 f(t)dt
Example:

For a fair six-sided die, the CDF for 
𝑋
=
3
X=3 is:
𝐹
(
3
)
=
𝑃
(
𝑋
≤
3
)
=
𝑃
(
𝑋
=
1
)
+
𝑃
(
𝑋
=
2
)
+
𝑃
(
𝑋
=
3
)
=
1
6
+
1
6
+
1
6
=
1
2
F(3)=P(X≤3)=P(X=1)+P(X=2)+P(X=3)= 
6
1
​
 + 
6
1
​
 + 
6
1
​
 = 
2
1
​
 
Importance:

The CDF is used to determine the probability that a random variable falls within a specific range and to understand the distribution of the variable.

# %%
Q3: Examples of Situations Where the Normal Distribution Might Be Used as a Model
Examples:

Heights of individuals in a population.
Scores on standardized tests.
Measurement errors in scientific experiments.
Parameters:

Mean (
𝜇
μ): Determines the center of the distribution.
Standard Deviation (
𝜎
σ): Determines the spread or width of the distribution.
The shape of the normal distribution is symmetric about the mean. A larger standard deviation results in a wider, flatter curve.

# %%
Q4: Importance of Normal Distribution with Real-Life Examples
Importance:

Many natural phenomena follow a normal distribution.
Central Limit Theorem: The sum of many independent random variables tends towards a normal distribution, regardless of the original distribution.
Real-Life Examples:

IQ scores.
Measurement errors.
Heights and weights of people.

# %%
Q5: What is Bernoulli Distribution? Example and Difference from Binomial Distribution
Bernoulli Distribution:

Represents the outcome of a single trial with two possible outcomes: success (1) and failure (0).
Parameter: 
𝑝
p (probability of success).
Example:

Flipping a coin (success = heads, failure = tails).
Difference from Binomial Distribution:

Bernoulli Distribution: Single trial, 
𝑋
∈
{
0
,
1
}
X∈{0,1}.
Binomial Distribution: Multiple trials (
𝑛
n), 
𝑋
∈
{
0
,
1
,
2
,
.
.
.
,
𝑛
}
X∈{0,1,2,...,n}, sum of 
𝑛
n independent Bernoulli trials.

# %%
Q6: Probability of Observation Greater than 60 in a Normal Distribution with Mean 50 and Standard Deviation 10
The Z-score formula:

𝑍
=
𝑋
−
𝜇
𝜎
Z= 
σ
X−μ
​
 
Given 
𝑋
=
60
X=60, 
𝜇
=
50
μ=50, 
𝜎
=
10
σ=10:

𝑍
=
60
−
50
10
=
1
Z= 
10
60−50
​
 =1
Using standard normal distribution tables:

𝑃
(
𝑍
>
1
)
=
1
−
𝑃
(
𝑍
≤
1
)
=
1
−
0.8413
=
0.1587
P(Z>1)=1−P(Z≤1)=1−0.8413=0.1587
So, the probability that a randomly selected observation will be greater than 60 is 
0.1587
0.1587 or 15.87%

# %%
Q7: Uniform Distribution with an Example
Uniform Distribution:

All outcomes are equally likely within a specific range.
Example:

Rolling a fair six-sided die.
The PDF of a continuous uniform distribution over the interval 
[
𝑎
,
𝑏
]
[a,b] is:
𝑓
(
𝑥
)
=
1
𝑏
−
𝑎
for
𝑎
≤
𝑥
≤
𝑏
f(x)= 
b−a
1
​
 fora≤x≤b

# %%
Q8: What is the Z-score? Importance of the Z-score
Z-score:

Measures the number of standard deviations a data point is from the mean.
Formula:
𝑍
=
𝑋
−
𝜇
𝜎
Z= 
σ
X−μ
​
 
Importance:

Standardizes different datasets.
Allows comparison between different datasets.
Helps identify outliers.

# %% [markdown]
# Q9: Central Limit Theorem and Its Significance
# Central Limit Theorem (CLT):
#
# States that the distribution of the sample mean of a large number of independent, identically distributed variables will be approximately normal, regardless of the original distribution.
# Significance:
#
# Justifies the use of the normal distribution in inferential statistics.
# Allows for the use of normal distribution techniques for hypothesis testing and confidence intervals, even when the underlying distribution is not normal.

# %%
Q10: Assumptions of the Central Limit Theorem
Independence: The sampled observations must be independent.
Sample Size: The sample size should be sufficiently large (commonly 
𝑛
≥
30
n≥30).
Identically Distributed: The population from which samples are drawn should have the same distribution.
These assumptions ensure the validity of the Central Limit Theorem in practical applications.
