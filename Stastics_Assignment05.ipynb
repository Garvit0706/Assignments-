# %% [markdown]
# Q1: What is Estimation Statistics? Explain point estimate and interval estimate.
# Estimation Statistics:
#
# A branch of statistics that provides methods for estimating unknown population parameters based on sample data.
# Two main types of estimates: point estimates and interval estimates.
# Point Estimate:
#
# A single value that serves as an estimate of a population parameter.
# Example: The sample mean (
# 𝑥
# ˉ
# x
# ˉ
#  ) is a point estimate of the population mean (
# 𝜇
# μ).
# Interval Estimate:
#
# A range of values within which the population parameter is expected to lie with a certain level of confidence.
# Example: A 95% confidence interval for the population mean might be (45, 55).

# %%
2.
import math

def estimate_population_mean(sample_mean, sample_std_dev, sample_size):
    # Calculate the standard error
    standard_error = sample_std_dev / math.sqrt(sample_size)
    return sample_mean, standard_error

# Example usage
sample_mean = 500
sample_std_dev = 50
sample_size = 50
mean, std_error = estimate_population_mean(sample_mean, sample_std_dev, sample_size)
print("Sample Mean:", mean)
print("Standard Error:", std_error)

# %%
Q3: What is Hypothesis Testing? Why is it used? Importance of Hypothesis Testing
Hypothesis Testing:

A statistical method that uses sample data to evaluate a hypothesis about a population parameter.
Helps determine whether there is enough evidence to reject a null hypothesis in favor of an alternative hypothesis.
Importance:

Provides a formal process for making inferences about population parameters based on sample data.
Helps in making data-driven decisions in various fields such as medicine, economics, and engineering.

# %%
Q4: Hypothesis About Average Weight of Male and Female College Students
Hypothesis:

Null Hypothesis (𝐻0H 0​): The average weight of male college students is equal to the average weight of female college students.
Alternative Hypothesis (
𝐻
1
H 
1
​
 ): The average weight of male college students is greater than the average weight of female college students.

# %%
5.
import scipy.stats as stats

# Sample data
sample1 = [85, 90, 78, 92, 88]
sample2 = [80, 75, 78, 85, 82]

# Perform t-test
t_stat, p_value = stats.ttest_ind(sample1, sample2)

print("t-statistic:", t_stat)
print("p-value:", p_value)

# %%
Q6: Null and Alternative Hypothesis Examples
Null Hypothesis (H0):

A statement that there is no effect or no difference.
Example: There is no difference in average test scores between two teaching methods.
Alternative Hypothesis (H1):

A statement that there is an effect or a difference.
Example: The average test scores are different between the two teaching methods.

# %%
Q7: Steps in Hypothesis Testing
State the hypotheses:

Null hypothesis (
𝐻
0
H 
0
​
 )
Alternative hypothesis (
𝐻
1
H 
1
​
 )
Choose the significance level (
𝛼
α):

Commonly used levels are 0.05, 0.01, and 0.10.
Collect data and calculate the test statistic:

Use sample data to compute the statistic (e.g., t-statistic, z-statistic).
Determine the p-value or critical value:

Compare the test statistic to a critical value or determine the p-value.
Make a decision:

If the p-value is less than 
𝛼
α, reject 
𝐻
0
H 
0
​
 .
If the p-value is greater than 
𝛼
α, fail to reject 
𝐻
0
H 
0
​
 .
Interpret the results:

Draw conclusions based on the hypothesis test.

# %%
Q8: Define p-value and Explain Its Significance in Hypothesis Testing
p-value:

The probability of obtaining test results at least as extreme as the observed results, assuming that the null hypothesis is true.
It quantifies the evidence against the null hypothesis.
Significance:

A small p-value (typically ≤ 0.05) indicates strong evidence against the null hypothesis, leading to its rejection.
A large p-value (> 0.05) indicates weak evidence against the null hypothesis, so it is not rejected.

# %%
9.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Degrees of freedom
df = 10

# Generate x values
x = np.linspace(-4, 4, 1000)
# Calculate the t-distribution
y = stats.t.pdf(x, df)

# Plot the t-distribution
plt.plot(x, y, label='t-distribution (df=10)')
plt.title("Student's t-Distribution")
plt.xlabel('t')
plt.ylabel('Probability Density')
plt.legend()
plt.show()

# %%
10.
import numpy as np
import scipy.stats as stats

# Sample data
sample1 = np.random.normal(5, 1, 30)
sample2 = np.random.normal(5.5, 1, 30)

# Perform two-sample t-test
t_stat, p_value = stats.ttest_ind(sample1, sample2)

print("t-statistic:", t_stat)
print("p-value:", p_value)

# %%
Q11: What is Student’s t Distribution? When to Use the t-Distribution
Student's t Distribution:

A probability distribution used to estimate population parameters when the sample size is small and/or the population variance is unknown.
It is similar to the normal distribution but has heavier tails, providing more room for variability.
When to Use:

When the sample size is small (typically 
𝑛
<
30
n<30).
When the population standard deviation is unknown.

# %%
Q12: What is t-Statistic? State the Formula for t-Statistic
t-Statistic:

A statistic used in hypothesis testing to determine if there is a significant difference between the means of two groups.
Formula for one-sample t-test:
𝑡
=
𝑥
ˉ
−
𝜇
𝑠
/
𝑛
t= 
s/ 
n
​
 
x
ˉ
 −μ
​
 

Where:
𝑥
ˉ
x
ˉ
  = sample mean
𝜇
μ = population mean
𝑠
s = sample standard deviation
𝑛
n = sample size

# %%
Q13: Estimate the Population Mean Revenue with a 95% Confidence Interval
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = $500
Sample standard deviation (
𝑠
s) = $50
Sample size (
𝑛
n) = 50
Using the formula for the confidence interval:

𝑥
ˉ
±
𝑡
𝛼
/
2
(
𝑠
𝑛
)
x
ˉ
 ±t 
α/2
​
 ( 
n
​
 
s
​
 )
Where 
𝑡
𝛼
/
2
t 
α/2
​
  is the critical value from the t-distribution with 
𝑛
−
1
n−1 degrees of freedom.
import scipy.stats as stats

# Sample data
sample_mean = 500
sample_std_dev = 50
sample_size = 50

# Degrees of freedom
df = sample_size - 1
# Confidence level
confidence_level = 0.95
alpha = 1 - confidence_level

# t-critical value
t_critical = stats.t.ppf(1 - alpha/2, df)

# Margin of error
margin_of_error = t_critical * (sample_std_dev / np.sqrt(sample_size))

# Confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("95% Confidence Interval:", confidence_interval)

# %%
Q14: Hypothesis Test for Blood Pressure Decrease
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 8 mmHg
Sample standard deviation (
𝑠
s) = 3 mmHg
Sample size (
𝑛
n) = 100
Hypothesized mean decrease (
𝜇
0
μ 
0
​
 ) = 10 mmHg
Significance level (
𝛼
α) = 0.05
Hypotheses:

𝐻
0
:
𝜇
=
10
H 
0
​
 :μ=10
𝐻
1
:
𝜇
≠
10
H 
1
​
 :μ

=10
Using the formula for the t-statistic:

𝑡
=
𝑥
ˉ
−
𝜇
0
𝑠
/
𝑛
t= 
s/ 
n
​
 
x
ˉ
 −μ 
0
​
 
​
import scipy.stats as stats

# Given data
sample_mean = 8
hypothesized_mean = 10
sample_std_dev = 3
sample_size = 100
alpha = 0.05

# t-statistic
t_stat = (sample_mean - hypothesized_mean) / (sample_std_dev / np.sqrt(sample_size))

# p-value
p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df=sample_size - 1))

print("t-statistic:", t_stat)
print("p-value:", p_value)

# Decision
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# %%
Q15: Hypothesis Test for Mean Weight
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 4.8 pounds
Population mean (
𝜇
0
μ 
0
​
 ) = 5 pounds
Sample standard deviation (
𝑠
s) = 0.5 pounds
Sample size (
𝑛
n) = 25
Significance level (
𝛼
α) = 0.01
Hypotheses:

𝐻
0
:
𝜇
=
5
H 
0
​
 :μ=5
𝐻
1
:
𝜇
<
5
H 
1
​
 :μ<5
Using the formula for the t-statistic:

𝑡
=
𝑥
ˉ
−
𝜇
0
𝑠
/
𝑛
t= 
s/ 
n
​
 
x
ˉ
 −μ 
0
​
 
​
import scipy.stats as stats

# Given data
sample_mean = 4.8
hypothesized_mean = 5
sample_std_dev = 0.5
sample_size = 25
alpha = 0.01

# t-statistic
t_stat = (sample_mean - hypothesized_mean) / (sample_std_dev / np.sqrt(sample_size))

# p-value (one-tailed test)
p_value = stats.t.cdf(t_stat, df=sample_size - 1)

print("t-statistic:", t_stat)
print("p-value:", p_value)

# Decision
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# %%
Q16: Hypothesis Test for Equality of Population Means
Given:

First group: 
𝑛
1
=
30
n 
1
​
 =30, mean 
𝑥
ˉ
1
=
80
x
ˉ
  
1
​
 =80, std 
𝑠
1
=
10
s 
1
​
 =10
Second group: 
𝑛
2
=
40
n 
2
​
 =40, mean 
𝑥
ˉ
2
=
75
x
ˉ
  
2
​
 =75, std 
𝑠
2
=
8
s 
2
​
 =8
Significance level (
𝛼
α) = 0.01
Hypotheses:

𝐻
0
:
𝜇
1
=
𝜇
2
H 
0
​
 :μ 
1
​
 =μ 
2
​
 
𝐻
1
:
𝜇
1
≠
𝜇
2
H 
1
​
 :μ 
1
​
 

=μ 
2
​
 
Using the formula for the two-sample t-test:

𝑡
=
𝑥
ˉ
1
−
𝑥
ˉ
2
(
𝑠
1
2
𝑛
1
)
+
(
𝑠
2
2
𝑛
2
)
t= 
( 
n 
1
​
 
s 
1
2
​
 
​
 )+( 
n 
2
​
 
s 
2
2
​
 
​
 )
​
 
x
ˉ
  
1
​
 − 
x
ˉ
  
2
​
 
​
import scipy.stats as stats
import numpy as np

# Given data
n1, mean1, std1 = 30, 80, 10
n2, mean2, std2 = 40, 75, 8
alpha = 0.01

# Pooled standard deviation
std_error = np.sqrt((std1**2 / n1) + (std2**2 / n2))

# t-statistic
t_stat = (mean1 - mean2) / std_error

# Degrees of freedom
df = min(n1 - 1, n2 - 1)

# p-value (two-tailed test)
p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df))

print("t-statistic:", t_stat)
print("p-value:", p_value)

# Decision
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# %%
Q17: Estimate Population Mean with 99% Confidence Interval
Given:

Sample mean (
𝑥
ˉ
x
ˉ
 ) = 4
Sample standard deviation (
𝑠
s) = 1.5
Sample size (
𝑛
n) = 50
Using the formula for the confidence interval:

𝑥
ˉ
±
𝑡
𝛼
/
2
(
𝑠
𝑛
)
x
ˉ
 ±t 
α/2
​
 ( 
n
​
 
s
​
 )
Where 
𝑡
𝛼
/
2
t 
α/2
​
  is the critical value from the t-distribution with 
𝑛
−
1
n−1 degrees of freedom.
import scipy.stats as stats
import numpy as np

# Given data
sample_mean = 4
sample_std_dev = 1.5
sample_size = 50
confidence_level = 0.99
alpha = 1 - confidence_level

# Degrees of freedom
df = sample_size - 1

# t-critical value
t_critical = stats.t.ppf(1 - alpha/2, df)

# Margin of error
margin_of_error = t_critical * (sample_std_dev / np.sqrt(sample_size))

# Confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("99% Confidence Interval:", confidence_interval)
